# %%
import matplotlib.pyplot as plt
import random
import time
# Generate a trend line
import 
# %matplotlib inline

# %%
def generate_RW(sample = 3000, mu = 0, sigma = 1):
    R = []
    
    for i in range(sample):
        # Establish randome walk formula E_t+1 = E_t + e
        e = random.gauss(mu, sigma)
        if i == 0:
            R.append(e)
        else:
            R.append(R[i-1] + e)
    
    return R

# %%
for j in range(3):
    tmp_RW = generate_RW()
    plt.plot(tmp_RW)
    plt.show()
    time.sleep(5)

# %%
# Trend equation: Tt = A + B···t + Et
# Tt = A + Ft + Et
length = 50 
a = 5
b = .5
c = 3
trend = [a + b * i for i in range(length)]
noise = [c * random.gauss(0, 1) for _ in range(length)]
ts = [trend[i] + noise[i] for i in range(length)]
plt.plot(ts)
plt.plot(trend)
plt.show()

# Seasonality - repetitive variations in a time series dataset 
# S_t+p = S_t 
# T_t = A + B_t +CS_t + E_t  
# vs Stationary
