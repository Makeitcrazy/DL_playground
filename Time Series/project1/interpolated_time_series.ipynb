# %%
import os
import pandas as pd
import matplotlib.pyplot as plt

# %%
def interpolated_time_series():
    
    ts_df = pd.read_csv('C:\\Users\\Terrence Poon\\Desktop\\ML_Learning\\Time Series\\project1\\MET Office Weather Data.csv')
    ts = ts_df.loc[ts_df['station'] == 'sheffield']['tmin'].interpolate().dropna().tolist()
    
    return ts

# %%
abc = interpolated_time_series()

# %%
abc
# Out:
# [347.527954,
#  359.840363,
#  357.854492,
#  356.464386,
#  365.003662,
#  365.003662,
#  388.635559,
#  392.011536,
#  393.60022,
#  374.33725,
#  373.34433,
#  377.117462,
#  365.003662,
#  366.790924,
#  368.18103,
#  378.309021,
#  367.386688,
#  372.351379,
#  381.48642,
#  375.528809,
#  363.216339,
#  362.422028,
#  351.896881,
#  344.549164,
#  346.336426,
#  345.144928,
#  349.116669,
#  350.109589,
#  339.981628,
#  335.414124,
#  333.031067,
#  332.633911,
#  322.704529,
#  330.250854,
#  330.846619,
#  336.208496,
#  331.640961,
#  329.65509,
#  324.094635,
#  327.073456,
#  317.938446,
#  318.53418,
#  304.633057,
#  297.483948,
#  292.916412,
#  300.462738,
#  309.796356,
#  305.427429,
#  297.285339,
#  295.895233,
#  293.512177,
#  301.455688,
#  302.051453,
#  298.27829,
#  300.859924,
#  301.058533,
#  310.39212,
#  312.775177,
#  308.40625,
#  310.590698,
#  307.810486,
#  322.704529,
#  321.910187,
#  320.718658,
#  321.314423,
#  324.889008,
#  322.307373,
# ...

# %%
if __name__ == '__main__':
    ts = interpolated_time_series()
    plt.plot(ts[-120:])
    plt.show()
