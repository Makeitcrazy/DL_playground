# %%
import pandas as pd
import os

# %%
def raw_time_series():
    if '__file__' in globals():
        path = os.path.dirname(os.path.abspath(__file__))
    else:
        path = os.getcwd()
        
    ts_df = pd.read_csv(r'C:\Users\Terrence Poon\Desktop\ML_Learning\Time Series\project1\MET Office Weather Data.csv')
    ts = ts_df.loc[ts_df['station'] == 'sheffield']['tmin'].tolist()
    return ts

# %%
anc = raw_time_series()

# %%
anc
# Out:
# [1.7,
#  2.8,
#  -1.6,
#  3.8,
#  6.2,
#  9.3,
#  10.5,
#  10.9,
#  10.0,
#  6.4,
#  3.5,
#  2.4,
#  3.5,
#  2.1,
#  2.5,
#  3.3,
#  6.4,
#  8.7,
#  11.8,
#  11.8,
#  10.5,
#  6.3,
#  3.4,
#  1.7,
#  0.4,
#  2.4,
#  0.8,
#  3.4,
#  4.4,
#  9.2,
#  11.4,
#  9.4,
#  7.8,
#  4.5,
#  3.3,
#  0.9,
#  -0.7,
#  -1.0,
#  0.2,
#  2.8,
#  5.7,
#  8.5,
#  11.5,
#  11.7,
#  9.8,
#  8.1,
#  3.8,
#  -0.5,
#  -0.6,
#  0.6,
#  0.1,
#  5.1,
#  5.3,
#  10.2,
#  12.6,
#  10.6,
#  8.0,
#  4.4,
#  2.6,
#  0.4,
#  1.0,
#  0.0,
#  -0.1,
#  2.7,
#  6.1,
#  8.4,
#  9.6,
#  10.2,
#  8.8,
#  4.5,
#  4.9,
#  2.7,
#  0.9,
#  0.6,
#  1.4,
#  3.6,
#  8.4,
#  10.5,
#  10.8,
#  11.3,
#  9.5,
#  5.5,
#  4.4,
#  1.4,
#  2.3,
#  1.1,
#  3.0,
#  2.9,
#  6.8,
#  10.0,
#  10.8,
#  10.8,
#  11.0,
#  7.0,
#  2.8,
#  -2.3,
#  -0.8,
#  1.4,
#  1.1,
#  1.9,
#  5.3,
#  9.7,
#  11.0,
#  10.9,
#  10.4,
#  6.1,
#  3.1,
#  1.0,
#  0.1,
#  0.4,
#  -0.7,
#  2.4,
#  6.8,
#  8.8,
#  9.8,
#  11.1,
#  8.7,
#  4.1,
#  3.9,
#  -0.3,
#  0.4,
#  1.6,
#  3.4,
#  3.8,
#  7.4,
#  10.0,
#  11.5,
#  12.7,
#  8.8,
#  6.5,
#  2.0,
#  1.8,
#  0.6,
#  1.5,
#  1.8,
#  5.1,
#  4.8,
#  9.4,
#  11.2,
#  10.6,
#  8.5,
#  6.0,
#  5.7,
#  2.8,
#  -2.5,
#  -4.2,
#  2.1,
#  4.2,
#  7.0,
#  9.6,
#  11.4,
#  12.0,
#  10.7,
#  3.9,
#  4.7,
#  1.5,
#  3.0,
#  2.0,
#  3.1,
#  5.3,
#  6.6,
#  11.2,
#  11.7,
#  10.6,
#  9.6,
#  4.0,
#  2.5,
#  1.9,
#  -0.8,
#  3.1,
#  3.3,
#  2.9,
#  5.1,
#  10.2,
#  11.3,
#  11.5,
#  8.5,
#  6.5,
#  5.2,
#  2.3,
#  4.5,
#  1.8,
#  1.0,
#  4.2,
#  5.9,
#  9.2,
#  10.9,
#  11.9,
#  10.9,
#  8.6,
#  4.8,
#  4.5,
#  2.2,
#  1.8,
#  1.6,
#  4.4,
#  5.1,
#  10.2,
#  13.0,
#  12.4,
#  9.6,
#  5.9,
#  6.2,
#  -0.1,
#  2.1,
#  -0.2,
#  0.7,
#  3.9,
#  6.0,
#  10.5,
#  13.3,
#  11.3,
#  9.6,
#  6.5,
#  5.1,
#  4.8,
#  0.7,
#  0.4,
#  1.0,
#  3.9,
#  6.3,
#  9.2,
#  13.5,
#  11.9,
#  10.0,
#  5.9,
#  2.9,
#  1.2,
#  2.5,
#  -0.8,
#  3.6,
#  3.1,
#  5.1,
#  9.3,
#  10.4,
#  9.9,
#  9.2,
#  6.9,
#  4.6,
#  2.7,
#  1.8,
#  4.1,
#  3.4,
#  2.7,
#  6.5,
#  8.7,
#  11.5,
#  10.7,
#  9.1,
#  7.3,
#  4.1,
#  1.2,
#  1.7,
#  0.8,
#  1.3,
#  5.2,
#  6.8,
#  9.1,
#  12.3,
#  11.1,
#  8.7,
#  6.8,
#  3.7,
#  1.6,
#  1.6,
#  2.5,
#  3.5,
#  3.8,
#  6.5,
#  10.0,
#  13.3,
#  11.0,
#  9.3,
#  4.5,
#  2.9,
#  3.0,
#  2.9,
#  0.4,
#  1.5,
#  2.2,
#  6.9,
#  9.9,
#  11.6,
#  12.8,
#  10.0,
#  7.8,
#  5.0,
#  0.8,
#  1.3,
#  0.4,
#  2.8,
#  3.8,
#  6.5,
#  9.0,
#  10.0,
#  10.6,
#  9.3,
#  6.7,
#  4.5,
#  2.2,
#  0.5,
#  2.8,
#  1.0,
#  2.3,
#  8.3,
#  9.4,
#  11.6,
#  10.6,
#  9.4,
#  9.0,
#  4.6,
#  1.5,
#  1.2,
#  0.5,
#  0.7,
#  4.1,
#  5.8,
#  8.2,
#  11.2,
#  11.5,
#  9.0,
#  6.9,
#  3.2,
#  1.6,
#  1.0,
#  2.1,
#  2.9,
#  3.2,
#  6.9,
#  10.4,
#  10.3,
#  11.6,
#  9.5,
#  8.2,
#  0.9,
#  4.0,
#  1.7,
#  2.5,
#  2.2,
#  4.1,
#  8.5,
#  9.6,
#  12.4,
#  13.4,
#  9.4,
#  6.5,
#  3.7,
#  3.8,
#  1.2,
#  2.5,
#  4.2,
#  4.3,
#  7.8,
#  10.0,
#  11.9,
#  9.6,
#  8.0,
#  5.2,
#  4.5,
#  4.1,
#  1.5,
#  2.2,
#  2.6,
#  4.0,
#  7.3,
#  9.8,
#  10.8,
#  11.1,
#  10.5,
#  8.2,
#  5.7,
#  3.4,
#  2.0,
#  4.2,
#  3.1,
#  5.2,
#  6.6,
#  10.0,
#  12.3,
#  12.0,
#  9.1,
#  7.9,
#  4.4,
#  2.4,
#  2.1,
#  1.3,
#  2.0,
#  4.0,
#  5.8,
#  9.5,
#  11.2,
#  11.6,
#  9.5,
#  6.5,
#  1.5,
#  2.8,
#  5.0,
#  1.0,
#  0.4,
#  4.4,
#  7.4,
#  8.0,
#  11.6,
#  12.6,
#  9.4,
#  7.5,
#  4.5,
#  0.5,
#  0.3,
#  -0.8,
#  -0.1,
#  1.4,
#  7.7,
#  10.3,
#  11.7,
#  12.2,
#  10.8,
#  4.4,
#  6.2,
#  0.7,
#  1.3,
#  3.7,
#  2.4,
#  3.4,
#  8.3,
#  9.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  2.2,
#  3.0,
#  3.7,
#  4.8,
#  7.5,
#  9.6,
#  10.8,
#  10.3,
#  9.4,
#  7.5,
#  4.9,
#  2.5,
#  4.5,
#  2.7,
#  4.1,
#  4.2,
#  6.7,
#  9.6,
#  12.7,
#  11.7,
#  10.3,
#  9.6,
#  2.4,
#  4.1,
#  0.9,
#  0.9,
#  1.6,
#  1.7,
#  8.3,
#  9.1,
#  9.9,
#  10.2,
#  8.9,
#  5.5,
#  3.7,
#  3.5,
#  4.1,
#  2.3,
#  3.3,
#  3.8,
#  5.4,
#  8.9,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  2.3,
#  1.2,
#  -0.3,
#  2.9,
#  7.6,
#  10.1,
#  11.5,
#  10.7,
#  10.3,
#  7.2,
#  5.1,
#  5.1,
#  2.7,
#  1.9,
#  2.4,
#  3.6,
#  7.7,
#  10.2,
#  12.6,
#  12.1,
#  8.2,
#  7.2,
#  1.6,
#  0.8,
#  2.2,
#  4.0,
#  3.2,
#  5.7,
#  6.0,
#  9.6,
#  13.0,
#  11.9,
#  10.4,
#  5.0,
#  3.3,
#  2.4,
#  2.7,
#  1.8,
#  3.9,
#  4.5,
#  6.3,
#  8.3,
#  11.9,
#  12.1,
#  9.6,
#  7.2,
#  3.7,
#  0.0,
#  2.5,
#  2.8,
#  2.9,
#  4.0,
#  6.3,
#  8.6,
#  12.2,
#  11.4,
#  8.8,
#  7.1,
#  5.3,
#  1.4,
#  0.3,
#  -2.5,
#  2.4,
#  2.9,
#  6.7,
#  9.3,
#  11.9,
#  11.2,
#  10.9,
#  6.4,
#  3.9,
#  3.1,
#  2.4,
#  0.6,
#  2.1,
#  4.8,
#  6.6,
#  10.5,
#  11.4,
#  11.9,
#  10.5,
#  7.6,
#  3.5,
#  1.8,
#  1.2,
#  1.6,
#  -0.3,
#  4.7,
#  7.2,
#  10.5,
#  12.3,
#  10.5,
#  9.1,
#  5.5,
#  5.1,
#  3.2,
#  3.3,
#  1.6,
#  2.0,
#  3.2,
#  6.8,
#  9.4,
#  12.7,
#  13.5,
#  9.4,
#  5.9,
#  4.5,
#  3.8,
#  0.2,
#  1.7,
#  3.0,
#  5.5,
#  8.3,
#  10.8,
#  13.6,
#  13.4,
#  11.1,
#  7.7,
#  4.5,
#  0.7,
#  1.8,
#  2.0,
#  1.8,
#  4.1,
#  7.4,
#  10.2,
#  13.4,
#  11.2,
#  10.2,
#  7.7,
#  4.7,
#  6.0,
#  3.0,
#  3.2,
#  3.6,
#  4.2,
#  5.3,
#  10.8,
#  12.7,
#  12.4,
#  9.5,
#  6.0,
#  4.2,
#  0.9,
#  1.3,
#  -0.8,
#  3.5,
#  3.0,
#  6.9,
#  10.2,
#  12.0,
#  12.5,
#  11.7,
#  6.9,
#  3.1,
#  2.7,
#  2.2,
#  2.7,
#  0.2,
#  5.2,
#  7.8,
#  10.4,
#  12.5,
#  12.5,
#  9.5,
#  7.9,
#  3.2,
#  1.2,
#  3.4,
#  2.7,
#  6.1,
#  4.3,
#  6.6,
#  10.6,
#  11.3,
#  12.1,
#  10.4,
#  7.4,
#  6.4,
#  1.7,
#  1.9,
#  2.6,
#  3.1,
#  4.7,
#  7.2,
#  9.2,
#  12.0,
#  12.6,
#  11.0,
#  5.3,
#  5.8,
#  2.6,
#  -3.5,
#  -0.8,
#  2.6,
#  4.4,
#  7.9,
#  11.6,
#  11.4,
#  11.7,
#  9.0,
#  6.9,
#  4.6,
#  2.3,
#  -1.4,
#  0.5,
#  1.1,
#  3.2,
#  5.2,
#  10.3,
#  13.5,
#  11.3,
#  11.4,
#  7.9,
#  3.8,
#  4.1,
#  -0.8,
#  -2.4,
#  1.5,
#  4.4,
#  6.8,
#  10.2,
#  11.5,
#  12.9,
#  10.2,
#  7.8,
#  4.1,
#  4.3,
#  2.2,
#  3.4,
#  3.4,
#  6.8,
#  7.2,
#  10.7,
#  11.6,
#  12.0,
#  10.0,
#  7.7,
#  4.3,
#  2.3,
#  3.4,
#  1.1,
#  2.5,
#  6.2,
#  7.0,
#  9.4,
#  12.8,
#  12.5,
#  9.1,
#  6.8,
#  3.7,
#  1.8,
#  -1.0,
#  4.2,
#  5.1,
#  6.0,
#  8.0,
#  10.9,
#  13.2,
#  11.9,
#  11.0,
#  8.9,
#  5.7,
#  3.0,
#  0.6,
#  3.5,
#  2.0,
#  6.3,
#  6.0,
#  9.5,
#  12.8,
#  11.1,
#  10.7,
#  7.5,
#  5.8,
#  1.3,
#  0.0,
#  -3.5,
#  0.2,
#  5.0,
#  8.5,
#  11.7,
#  13.6,
#  13.3,
#  11.1,
#  8.2,
#  4.7,
#  3.4,
#  2.6,
#  2.3,
#  4.0,
#  4.9,
#  6.5,
#  9.7,
#  11.7,
#  11.5,
#  10.8,
#  7.2,
#  4.9,
#  3.0,
#  3.0,
#  2.8,
#  1.9,
#  6.0,
#  6.7,
#  9.9,
#  12.7,
#  12.5,
#  12.3,
#  8.1,
#  4.0,
#  3.3,
#  2.3,
#  1.8,
#  4.0,
#  3.4,
#  6.8,
#  11.4,
#  12.2,
#  11.8,
#  9.6,
#  7.0,
#  3.3,
#  -0.3,
#  1.6,
#  1.0,
#  0.9,
#  3.4,
#  5.8,
#  9.4,
#  12.3,
#  11.2,
#  10.7,
#  6.5,
#  6.0,
#  2.6,
#  0.7,
#  0.9,
#  3.5,
#  5.4,
#  9.0,
#  10.3,
#  12.9,
#  12.0,
#  8.1,
#  6.2,
#  2.3,
#  1.5,
#  2.4,
#  2.6,
#  2.0,
#  3.4,
#  8.5,
#  10.7,
#  12.0,
#  12.4,
#  10.3,
#  6.5,
#  6.3,
#  5.0,
#  1.0,
#  -0.2,
#  2.4,
#  4.1,
#  7.4,
#  9.9,
#  10.9,
#  11.0,
#  9.0,
#  9.2,
#  4.1,
#  4.3,
#  0.5,
#  -0.9,
#  -0.1,
#  5.9,
#  5.7,
#  9.3,
#  12.8,
#  13.5,
#  11.0,
#  6.5,
#  5.2,
#  2.9,
#  1.5,
#  -1.8,
#  2.3,
#  2.7,
#  7.7,
#  9.4,
#  12.4,
#  10.2,
#  10.7,
#  6.9,
#  4.4,
#  3.7,
#  2.9,
#  2.0,
#  5.8,
#  4.8,
#  6.3,
#  10.1,
#  12.9,
#  12.0,
#  9.6,
#  7.7,
#  4.9,
#  2.2,
#  1.1,
#  1.6,
#  0.8,
#  3.8,
#  7.4,
#  9.7,
#  12.2,
#  12.2,
#  11.7,
#  7.7,
#  4.4,
#  2.7,
#  -0.2,
#  2.7,
#  4.3,
#  5.9,
#  8.0,
#  10.9,
#  13.1,
#  13.2,
#  10.6,
#  8.3,
#  4.5,
#  3.4,
#  1.9,
#  1.2,
#  3.1,
#  5.5,
#  8.8,
#  11.5,
#  11.4,
#  11.4,
#  9.9,
#  7.5,
#  4.7,
#  2.3,
#  1.1,
#  4.2,
#  5.4,
#  6.0,
#  6.9,
#  10.4,
#  11.3,
#  11.8,
#  11.3,
#  7.7,
#  4.1,
#  -0.2,
#  2.1,
#  1.9,
#  -0.6,
#  3.9,
#  6.2,
#  9.3,
#  10.8,
#  10.8,
#  9.3,
#  7.4,
#  2.9,
#  -0.6,
#  -2.9,
#  -3.5,
#  1.6,
#  4.4,
#  6.4,
#  10.3,
#  11.0,
#  10.6,
#  9.2,
#  7.4,
#  5.4,
#  1.0,
#  1.0,
#  1.7,
#  1.2,
#  5.4,
#  8.7,
#  10.1,
#  11.9,
#  11.5,
#  9.3,
#  5.7,
#  4.7,
#  0.4,
#  1.4,
#  1.5,
#  1.0,
#  4.3,
#  7.6,
#  10.4,
#  10.5,
#  11.1,
#  9.3,
#  7.6,
#  1.9,
#  2.0,
#  0.6,
#  2.5,
#  3.5,
#  3.5,
#  ...]
